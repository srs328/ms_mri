# %% [markdown]
# # Choroid Plexus Segmentation Training via Auto3DSeg

# %%
import os
import json
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import glob
import random
import platform
from monai.apps.auto3dseg import AutoRunner
from monai.config import print_config
import importlib
from dataclasses import asdict
from loguru import logger
import sys

from reload_recursive import reload_recursive

import mri_data
import monai_training

print_config()
# Out:
# MONAI version: 1.4.0
# Numpy version: 1.26.4
# Pytorch version: 2.5.1+cu124
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 46a5272196a6c2590ca2589029eed8e4d56ff008
# MONAI __file__: /home/<username>/.virtualenvs/monai/lib/python3.12/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.3.2
# scikit-image version: NOT INSTALLED or UNKNOWN VERSION.
# scipy version: 1.14.1
# Pillow version: 11.0.0
# Tensorboard version: NOT INSTALLED or UNKNOWN VERSION.
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: NOT INSTALLED or UNKNOWN VERSION.
# tqdm version: 4.66.6
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 6.1.0
# pandas version: 2.2.3
# einops version: NOT INSTALLED or UNKNOWN VERSION.
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: 2.17.2
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
reload_recursive(monai_training)
reload_recursive(mri_data)

from mri_data.file_manager import scan_3Tpioneer_bids, filter_first_ses
from monai_training.preprocess import DataSetProcesser
from monai_training import training, preprocess

# %%
logger.remove()
logger.add(sys.stderr, level="DEBUG")
# Out:
# 2

# %%
load_data = True

# %%
hostname = platform.node()
if hostname == "rhinocampus" or hostname == "ryzen9":
    drive_root = Path("/media/smbshare")
else:
    drive_root = Path("/mnt/h")

projects_root = Path("/home/srs-9/Projects")
msmri_home = projects_root / "ms_mri"
training_work_dirs = msmri_home / "training_work_dirs"

dataroot = drive_root / "3Tpioneer_bids"
work_dir_name = "choroid_pineal_pituitary1"
work_dir = training_work_dirs / work_dir_name
modalities = ["flair", "t1"]
labels = ["choroid_t1_flair", "pineal", "pituitary"]

# %% [markdown]
# ## Prep the database
#
# Get the data and labels organized

# %%
if load_data:
    datalist_file = os.path.join(work_dir, "datalist.json")
    with open(datalist_file, 'r') as f:
        datalist = json.load(f)

    dataset = preprocess.parse_datalist(datalist_file, dataroot)

# %%
subs = sorted([int(scan.subid) for scan in dataset])
print(subs)
# Out:
# [1010, 1011, 1019, 1033, 1065, 1080, 1109, 1119, 1163, 1188, 1191, 1234, 1259, 1265, 1272, 1280, 1293, 1321, 1355, 1437, 1486, 1498, 1518, 1547, 1548, 2081, 2083, 2144]

# %%
if not load_data:
    dataset_proc = DataSetProcesser.new_dataset(dataroot, scan_3Tpioneer_bids, filters=[filter_first_ses])
    dataset_proc.prepare_images(modalities)
    dataset_proc.prepare_labels(labels, suffix_list=["CH", "SRS", "ED", "DT"])

    dataset = dataset_proc.dataset
    dataset.sort()
# Out:
# 2024-11-05 18:22:02.576 | INFO     | monai_training.preprocess:prepare_images:107 - Prepare Images
#  26%|██▌       | 148/575 [00:00<00:01, 216.97it/s]2024-11-05 18:22:03.330 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=2085, sesid=20170130)
#  30%|██▉       | 170/575 [00:00<00:01, 209.22it/s]2024-11-05 18:22:03.448 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=1394, sesid=20191012)
#  37%|███▋      | 212/575 [00:00<00:01, 205.25it/s]2024-11-05 18:22:03.668 | INFO     | mri_data.utils:merge_images:29 - fslmerge -a /media/smbshare/3Tpioneer_bids/sub-ms1196/ses-20161004/flair.t1.nii.gz /media/smbshare/3Tpioneer_bids/sub-ms1196/ses-20161004/flair.nii.gz /media/smbshare/3Tpioneer_bids/sub-ms1196/ses-20161004/t1.nii.gz
# Image Exception : #22 :: Failed to read volume /media/smbshare/3Tpioneer_bids/sub-ms1196/ses-20161004/t1.nii.gz
# Error : Error: short read, file may be truncated
# terminate called after throwing an instance of 'std::runtime_error'
#   what():  Failed to read volume /media/smbshare/3Tpioneer_bids/sub-ms1196/ses-20161004/t1.nii.gz
# Error : Error: short read, file may be truncated
# 2024-11-05 18:22:08.807 | ERROR    | monai_training.preprocess:prepare_images:147 - Something went wrong merging images for <bound method Scan.info of Scan(subid='1196', sesid='20161004', _dataroot=PosixPath('/media/smbshare/3Tpioneer_bids'), _root=PosixPath('/media/smbshare/3Tpioneer_bids/sub-ms1196/ses-20161004'), image=None, label=None, cond=None, id=24112560784)>
#  44%|████▍     | 253/575 [00:06<00:18, 17.54it/s]
# /home/srs-9/fsl/share/fsl/bin/fslmerge: line 2: 35395 Aborted                 (core dumped) /home/srs-9/fsl/bin/fslmerge "$@"
#  51%|█████▏    | 295/575 [00:06<00:08, 33.00it/s]2024-11-05 18:22:09.205 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=2106, sesid=20170205)
#  69%|██████▉   | 398/575 [00:07<00:01, 108.62it/s]2024-11-05 18:22:09.684 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=2001, sesid=20161222)
#  76%|███████▋  | 439/575 [00:07<00:00, 140.33it/s]2024-11-05 18:22:09.893 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=1364, sesid=20170705)
#  83%|████████▎ | 480/575 [00:07<00:00, 166.30it/s]2024-11-05 18:22:10.124 | INFO     | mri_data.utils:merge_images:29 - fslmerge -a /media/smbshare/3Tpioneer_bids/sub-ms2120/ses-20170920/flair.t1.nii.gz /media/smbshare/3Tpioneer_bids/sub-ms2120/ses-20170920/flair.nii.gz /media/smbshare/3Tpioneer_bids/sub-ms2120/ses-20170920/t1.nii.gz
# Image Exception : #22 :: Failed to read volume /media/smbshare/3Tpioneer_bids/sub-ms2120/ses-20170920/flair.nii.gz
# Error : Error: short read, file may be truncated
# terminate called after throwing an instance of 'std::runtime_error'
#   what():  Failed to read volume /media/smbshare/3Tpioneer_bids/sub-ms2120/ses-20170920/flair.nii.gz
# Error : Error: short read, file may be truncated
# 2024-11-05 18:22:11.707 | ERROR    | monai_training.preprocess:prepare_images:147 - Something went wrong merging images for <bound method Scan.info of Scan(subid='2120', sesid='20170920', _dataroot=PosixPath('/media/smbshare/3Tpioneer_bids'), _root=PosixPath('/media/smbshare/3Tpioneer_bids/sub-ms2120/ses-20170920'), image=None, label=None, cond=None, id=42762350400)>
#  91%|█████████ | 521/575 [00:09<00:01, 45.91it/s] 2024-11-05 18:22:11.867 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=1245, sesid=20220219)
# /home/srs-9/fsl/share/fsl/bin/fslmerge: line 2: 35426 Aborted                 (core dumped) /home/srs-9/fsl/bin/fslmerge "$@"
#  94%|█████████▍| 541/575 [00:09<00:00, 59.25it/s]2024-11-05 18:22:11.976 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=1229, sesid=20170715)
#  98%|█████████▊| 562/575 [00:09<00:00, 75.61it/s]2024-11-05 18:22:12.088 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=1379, sesid=20161022)
# 100%|██████████| 575/575 [00:09<00:00, 60.26it/s]
# 2024-11-05 18:22:12.119 | INFO     | monai_training.preprocess:prepare_labels:167 - Prepare Labels
# 2024-11-05 18:22:12.119 | DEBUG    | monai_training.preprocess:prepare_labels:178 - choroid_t1_flair.pineal.pituitary.nii.gz
#   0%|          | 0/565 [00:00<?, ?it/s]2024-11-05 18:22:12.127 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-05 18:22:12.127 | INFO     | mri_data.utils:combine_labels:86 - Combining labels for Scan(subid=1027, sesid=20170127)
# 2024-11-05 18:22:12.134 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:12.134 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:12.134 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:12.134 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-05 18:22:12.135 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-05 18:22:12.135 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1027, sesid=20170127)
# 2024-11-05 18:22:12.139 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-05 18:22:12.140 | INFO     | mri_data.utils:combine_labels:86 - Combining labels for Scan(subid=2205, sesid=20201218)
# 2024-11-05 18:22:12.146 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:12.146 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:12
| DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:26.150 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:26.150 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.150 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-05 18:22:26.150 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-05 18:22:26.150 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2073, sesid=20170904)
# 2024-11-05 18:22:26.159 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-05 18:22:26.159 | INFO     | mri_data.utils:combine_labels:86 - Combining labels for Scan(subid=2084, sesid=20170511)
# 2024-11-05 18:22:26.166 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:26.166 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:26.167 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.167 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-05 18:22:26.167 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-05 18:22:26.167 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2084, sesid=20170511)
# 2024-11-05 18:22:26.172 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-05 18:22:26.172 | INFO     | mri_data.utils:combine_labels:86 - Combining labels for Scan(subid=1113, sesid=20170526)
# 2024-11-05 18:22:26.178 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:26.179 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:26.179 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.179 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-05 18:22:26.179 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-05 18:22:26.179 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1113, sesid=20170526)
# 2024-11-05 18:22:26.185 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-05 18:22:26.185 | INFO     | mri_data.utils:combine_labels:86 - Combining labels for Scan(subid=1311, sesid=20161005)
# 2024-11-05 18:22:26.191 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:26.191 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:26.192 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.192 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-05 18:22:26.192 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-05 18:22:26.192 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1311, sesid=20161005)
# 2024-11-05 18:22:26.201 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-05 18:22:26.201 | INFO     | mri_data.utils:combine_labels:86 - Combining labels for Scan(subid=2178, sesid=20170406)
# 2024-11-05 18:22:26.208 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:26.208 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:26.208 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.208 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-05 18:22:26.209 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-05 18:22:26.209 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2178, sesid=20170406)
# 2024-11-05 18:22:26.337 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-05 18:22:26.337 | INFO     | mri_data.utils:combine_labels:86 - Combining labels for Scan(subid=1340, sesid=20170906)
# 2024-11-05 18:22:26.344 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:26.345 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:26.345 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.345 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-05 18:22:26.345 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-05 18:22:26.346 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1340, sesid=20170906)
#  99%|█████████▉| 562/565 [00:14<00:00, 32.52it/s]2024-11-05 18:22:26.350 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-05 18:22:26.351 | INFO     | mri_data.utils:combine_labels:86 - Combining labels for Scan(subid=1547, sesid=20220321)
# 2024-11-05 18:22:26.355 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:26.356 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair_ed.nii.gz
# 2024-11-05 18:22:26.356 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.356 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair.nii.gz
# 2024-11-05 18:22:26.356 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.pineal-srs.pituitary-ch.nii.gz
# 2024-11-05 18:22:26.356 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:26.357 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair_ed.nii.gz
# 2024-11-05 18:22:26.357 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.357 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair.nii.gz
# 2024-11-05 18:22:26.357 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.pineal-srs.pituitary-ch.nii.gz
# 2024-11-05 18:22:26.357 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.358 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair_ed.nii.gz
# 2024-11-05 18:22:26.358 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.358 | DEBUG    | mri_data.file_manager:find_label:405 - Found choroid_t1_flair-ED.nii.gz for Scan(subid=1547, sesid=20220321)
# 2024-11-05 18:22:26.364 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pineal-ch.nii.gz
# 2024-11-05 18:22:26.364 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pineal_srs.nii.gz
# 2024-11-05 18:22:26.364 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pineal-srs.nii.gz
# 2024-11-05 18:22:26.365 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pineal-srs.nii.gz
# 2024-11-05 18:22:26.365 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pineal_srs.nii.gz
# 2024-11-05 18:22:26.365 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pineal-srs.nii.gz
# 2024-11-05 18:22:26.365 | DEBUG    | mri_data.file_manager:find_label:405 - Found pineal-SRS.nii.gz for Scan(subid=1547, sesid=20220321)
# 2024-11-05 18:22:26.370 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pituitary-ch.nii.gz
# 2024-11-05 18:22:26.370 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pituitary_ch.nii.gz
# 2024-11-05 18:22:26.370 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pituitary-ch.nii.gz
# 2024-11-05 18:22:26.371 | DEBUG    | mri_data.file_manager:find_label:405 - Found pituitary-CH.nii.gz for Scan(subid=1547, sesid=20220321)
# 2024-11-05 18:22:26.371 | DEBUG    | mri_data.utils:combine_labels:102 - /media/smbshare/3Tpioneer_bids/sub-ms1547/ses-20220321/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz exists
# 2024-11-05 18:22:26.371 | SUCCESS  | monai_training.preprocess:log:22 - Saved /media/smbshare/3Tpioneer_bids/sub-ms1547/ses-20220321/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz
# 2024-11-05 18:22:26.376 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-05 18:22:26.376 | INFO     | mri_data.utils:combine_labels:86 - Combining labels for Scan(subid=1078, sesid=20180412)
# 2024-11-05 18:22:26.382 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:26.382 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:26.382 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.383 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-05 18:22:26.383 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-05 18:22:26.383 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1078, sesid=20180412)
# 2024-11-05 18:22:26.388 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-05 18:22:26.388 | INFO     | mri_data.utils:combine_labels:86 - Combining labels for Scan(subid=1211, sesid=20170117)
# 2024-11-05 18:22:26.394 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-05 18:22:26.394 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-05 18:22:26.394 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-05 18:22:26.394 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-05 18:22:26.395 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-05 18:22:26.395 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1211, sesid=20170117)
# 100%|██████████| 565/565 [00:14<00:00, 39.58it/s]
# 2024-11-05 18:22:26.395 | INFO     | monai_training.preprocess:prepare_labels:229 - Dataset size: 29

# %%
if not load_data:
    dataset = training.assign_conditions(dataset, 0.2)
    dataset[0]

# %%
if not load_data:
    training_data = []
    test_data = []

    for scan in dataset:
        if scan.cond == 'tr':
            training_data.append({"image": scan.image, "label": scan.label})
        elif scan.cond == 'ts':
            test_data.append(scan.image)

# %% [markdown]
# ## Review

# %%
def display_slices(scan):
    img1 = nib.load(scan.image_path)
    img2 = nib.load(scan.label_path)

    data1 = img1.get_fdata()[:,:,:]
    data2 = img2.get_fdata()

    slice_sums = np.sum(data2, axis=(0, 1))
    
    print(slice_sums)

    max_slice_index = np.argmax(slice_sums)
    print(f"Max slice: {max_slice_index}")

    slice1 = data1[:, :, max_slice_index]
    slice2 = data2[:, :, max_slice_index]    

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(slice1, cmap='gray')
    plt.title(f"Image 1 - Slice {max_slice_index}")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(slice2, cmap='gray')
    plt.title(f"Image 2 - Slice {max_slice_index}")
    plt.axis('off')
    plt.show()

# %%
# display_slices(dataset[20])

# %% [markdown]
# In the original code, they include labels in the test data as well. Also they have a function that checks that there is nonzero number of voxels in the label

# %%
#? I don't know why they put labels for the test data. the brats segmentation code didn't.
# train_data = [{'image': path + '/flair.nii.gz', 'label': path + '/flair_chp_mask_qced.nii.gz'} for path in train_exams]
# test_data = [{'image': path + '/flair.nii.gz', 'label': path + '/flair_chp_mask_qced.nii.gz'} for path in test_exams]
if not load_data:
    train_data = []
    test_data = []
    for scan in dataset:
        if scan.cond == 'tr' and scan.has_label:
            train_data.append({"image": str(scan.image_path), "label": str(scan.label_path)})
        elif scan.cond == 'ts' and scan.has_label():
            test_data.append({"image": str(scan.image_path), "label": str(scan.label_path)})


    print(f"Train num total: {len(train_data)}")
    print(f"Test num: {len(test_data)}")
# Out:
# Train num total: 24
# Test num: 5

# %% [markdown]
# Create and save datalist

# %%
if not load_data:
    n_folds = 5
    datalist = {
        "testing": test_data,
        "training": [{"fold": i % n_folds, "image": c["image"], "label": c["label"]} for i,c in enumerate(train_data)]
    }

    if not os.path.isdir(work_dir):
        os.makedirs(work_dir)

    # dataroot_dir = "/mnt/h"
    # if not os.path.isdir(dataroot_dir):
    #     os.makedirs(dataroot_dir)

    datalist_file = os.path.join(work_dir, "datalist.json")
    with open(datalist_file, "w") as f:
        json.dump(datalist, f)

# %% [markdown]
# Load datalist

# %%
datalist['testing']
# Out:
# [{'image': '/media/smbshare/3Tpioneer_bids/sub-ms1010/ses-20180208/flair.t1.nii.gz',
#   'label': '/media/smbshare/3Tpioneer_bids/sub-ms1010/ses-20180208/choroid_t1_flair-CH.pineal-CH.pituitary-CH.nii.gz'},
#  {'image': '/media/smbshare/3Tpioneer_bids/sub-ms1188/ses-20200720/flair.t1.nii.gz',
#   'label': '/media/smbshare/3Tpioneer_bids/sub-ms1188/ses-20200720/choroid_t1_flair-ED.pineal-CH.pituitary-CH.nii.gz'},
#  {'image': '/media/smbshare/3Tpioneer_bids/sub-ms1293/ses-20161129/flair.t1.nii.gz',
#   'label': '/media/smbshare/3Tpioneer_bids/sub-ms1293/ses-20161129/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz'},
#  {'image': '/media/smbshare/3Tpioneer_bids/sub-ms1355/ses-20210104/flair.t1.nii.gz',
#   'label': '/media/smbshare/3Tpioneer_bids/sub-ms1355/ses-20210104/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz'},
#  {'image': '/media/smbshare/3Tpioneer_bids/sub-ms2144/ses-20190422/flair.t1.nii.gz',
#   'label': '/media/smbshare/3Tpioneer_bids/sub-ms2144/ses-20190422/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz'}]

# %%
missing_images = []
missing_labels = []
for scan in dataset:
    if not scan.image_path.is_file():
        missing_images.append(scan.image_path)
    if not scan.label_path.is_file():
        missing_images.append(scan.label_path)
print(missing_images)
print(missing_labels)
# Out:
# []
# []

# %%
runner = AutoRunner(
    work_dir=work_dir,
    algos=["swinunetr"],
    input={
        "modality": "MRI",
        "datalist": str(datalist_file),
        "dataroot": str(dataroot),
    },
)
# Out:
# 2024-11-05 18:22:55,008 - INFO - AutoRunner using work directory /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary1
# 2024-11-05 18:22:55,009 - INFO - Found num_fold 5 based on the input datalist /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary1/datalist.json.
# 2024-11-05 18:22:55,010 - INFO - Setting num_fold 5 based on the input datalist /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary1/datalist.json.
# 2024-11-05 18:22:55,017 - INFO - Using user defined command running prefix , will override other settings
# /home/srs-9/.virtualenvs/monai/lib/python3.12/site-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
max_epochs = 100

train_param = {
    "num_epochs_per_validation": 1,
    #"num_images_per_batch": 2,
    "num_epochs": max_epochs,
    "num_warmup_epochs": 1,
}
runner.set_training_params(train_param)

# %%
runner.run()
# Out:
# 2024-11-05 18:22:58,228 - INFO - Running data analysis...
# 2024-11-05 18:22:58,233 - INFO - Found 0 GPUs for data analyzing!
# 2024-11-05 18:22:58,237 - INFO - device=cuda:0 but CUDA device is not available, using CPU instead.
#   0%|          | 0/24 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 runner.run()
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/monai/apps/auto3dseg/auto_runner.py:813, in AutoRunner.run(self)
#     809 logger.info("Running data analysis...")
#     810 da = DataAnalyzer(
#     811     self.datalist_filename, self.dataroot, output_path=self.datastats_filename, **self.analyze_params
#     812 )
# --> 813 da.get_all_case_stats()
#     815 da = None  # type: ignore
#     816 torch.cuda.empty_cache()
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/monai/apps/auto3dseg/data_analyzer.py:230, in DataAnalyzer.get_all_case_stats(self, key, transform_list)
#     228             result_bycase[DataStatsKeys.BY_CASE].extend(_[DataStatsKeys.BY_CASE])
#     229 else:
# --> 230     result_bycase = self._get_all_case_stats(0, 1, None, key, transform_list)
#     232 summarizer = SegSummarizer(
#     233     self.image_key,
#     234     self.label_key,
#    (...)
#     239     histogram_only=self.histogram_only,
#     240 )
#     241 n_cases = len(result_bycase[DataStatsKeys.BY_CASE])
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/monai/apps/auto3dseg/data_analyzer.py:333, in DataAnalyzer._get_all_case_stats(self, rank, world_size, manager_list, key, transform_list)
#     330 if not has_tqdm:
#     331     warnings.warn("tqdm is not installed. not displaying the caching progress.")
# --> 333 for batch_data in tqdm(dataloader) if (has_tqdm and rank == 0) else dataloader:
#     334     batch_data = batch_data[0]
#     335     try:
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1448, in _MultiProcessingDataLoaderIter._next_data(self)
#    1445     return self._process_data(data)
#    1447 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1448 idx, data = self._get_data()
#    1449 self._tasks_outstanding -= 1
#    1450 if self._dataset_kind == _DatasetKind.Iterable:
#    1451     # Check for _IterableDatasetStopIteration
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1412, in _MultiProcessingDataLoaderIter._get_data(self)
#    1408     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1409     # need to call `.task_done()` because we don't use `.join()`.
#    1410 else:
#    1411     while True:
# -> 1412         success, data = self._try_get_data()
#    1413         if success:
#    1414             return data
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1243, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1230 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1231     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1232     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1240     # Returns a 2-tuple:
#    1241     #   (bool: whether successfully get data, any: data if successful else None)
#    1242     try:
# -> 1243         data = self._data_queue.get(timeout=timeout)
#    1244         return (True, data)
#    1245     except Exception as e:
#    1246         # At timeout and error, we manually check whether any worker has
#    1247         # failed. Note that this is the only mechanism for Windows to detect
#    1248         # worker failures.
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/multiprocessing/connection.py:440, in Connection._poll(self, timeout)
#     439 def _poll(self, timeout):
# --> 440     r = wait([self], timeout)
#     441     return bool(r)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/multiprocessing/connection.py:1136, in wait(object_list, timeout)
#    1133     deadline = time.monotonic() + timeout
#    1135 while True:
# -> 1136     ready = selector.select(timeout)
#    1137     if ready:
#    1138         return [key.fileobj for (key, events) in ready]
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
scan_path = "/mnt/t/Data/3Tpioneer_bids/sub-ms1001/ses-20170215/proc/lesion_index.t3m20-mni_reg.nii.gz"
img = nib.load(scan_path)
