# %% [markdown]
# # Choroid Plexus Segmentation Training via Auto3DSeg

# %%
import os
import json
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import glob
import random
import platform
from monai.apps.auto3dseg import AutoRunner
from monai.config import print_config
import importlib
from dataclasses import asdict
from loguru import logger
import sys

from reload_recursive import reload_recursive

import mri_data
import monai_training

print_config()
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# MONAI version: 1.3.2
# Numpy version: 1.26.4
# Pytorch version: 2.4.0+cu121
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 59a7211070538586369afd4a01eca0a7fe2e742e
# MONAI __file__: /home/<username>/.virtualenvs/monai/lib/python3.12/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: 5.4.0
# Nibabel version: 5.3.2
# scikit-image version: 0.24.0
# scipy version: 1.14.1
# Pillow version: 11.0.0
# Tensorboard version: 2.18.0
# gdown version: 5.2.0
# TorchVision version: 0.20.1+cu124
# tqdm version: 4.66.6
# lmdb version: 1.5.1
# psutil version: 6.1.0
# pandas version: 2.2.3
# einops version: 0.8.0
# transformers version: 4.46.2
# mlflow version: 2.17.2
# pynrrd version: 1.1.1
# clearml version: 1.16.5
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
reload_recursive(monai_training)
reload_recursive(mri_data)

from mri_data.file_manager import scan_3Tpioneer_bids, filter_first_ses
from monai_training.preprocess import DataSetProcesser
from monai_training import training, preprocess

# %%
logger.remove()
logger.add(sys.stderr, level="DEBUG")
# Out:
# 1

# %%
load_data = False

# %%
hostname = platform.node()
if hostname == "rhinocampus" or hostname == "ryzen9":
    drive_root = Path("/media/smbshare")
else:
    drive_root = Path("/mnt/h")

projects_root = Path("/home/srs-9/Projects")
msmri_home = projects_root / "ms_mri"
training_work_dirs = msmri_home / "training_work_dirs"

dataroot = drive_root / "3Tpioneer_bids"
work_dir_name = "choroid_pineal_pituitary2"
work_dir = training_work_dirs / work_dir_name
modalities = ["flair", "t1"]
labels = ["choroid_t1_flair", "pineal", "pituitary"]

# %% [markdown]
# ## Prep the database
#
# Get the data and labels organized

# %%
if load_data:
    datalist_file = os.path.join(work_dir, "datalist.json")
    with open(datalist_file, 'r') as f:
        datalist = json.load(f)

    dataset = preprocess.parse_datalist(datalist_file, dataroot)
# Out:
# 2024-11-08 17:07:52.124 | INFO     | monai_training.preprocess:parse_datalist:282 - Loading /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/datalist.json
# 2024-11-08 17:07:52.124 | INFO     | monai_training.preprocess:parse_datalist:283 - /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/datalist.json exists: True

# %%
if not load_data:
    dataset_proc = DataSetProcesser.new_dataset(dataroot, scan_3Tpioneer_bids, filters=[filter_first_ses])
    dataset_proc.prepare_images(modalities)
    dataset_proc.prepare_labels(labels, suffix_list=["CH", "SRS", "ED", "DT"], resave=True)

    dataset = dataset_proc.dataset
    dataset.sort()
# Out:
# 2024-11-10 17:08:36.123 | INFO     | monai_training.preprocess:prepare_images:107 - Prepare Images
#   7%|▋         | 42/575 [00:01<00:16, 31.71it/s]2024-11-10 17:08:37.526 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=1229, sesid=20170715)
#  29%|██▉       | 168/575 [00:04<00:09, 41.64it/s]2024-11-10 17:08:40.845 | INFO     | mri_data.utils:merge_images:29 - fslmerge -a /mnt/h/3Tpioneer_bids/sub-ms1196/ses-20161004/flair.t1.nii.gz /mnt/h/3Tpioneer_bids/sub-ms1196/ses-20161004/flair.nii.gz /mnt/h/3Tpioneer_bids/sub-ms1196/ses-20161004/t1.nii.gz
# Image Exception : #22 :: Failed to read volume /mnt/h/3Tpioneer_bids/sub-ms1196/ses-20161004/t1.nii.gz
# Error : Error: short read, file may be truncated
# terminate called after throwing an instance of 'std::runtime_error'
#   what():  Failed to read volume /mnt/h/3Tpioneer_bids/sub-ms1196/ses-20161004/t1.nii.gz
# Error : Error: short read, file may be truncated
#  29%|██▉       | 168/575 [00:19<00:09, 41.64it/s]2024-11-10 17:09:05.953 | ERROR    | monai_training.preprocess:prepare_images:147 - Something went wrong merging images for <bound method Scan.info of Scan(subid='1196', sesid='20161004', _dataroot=PosixPath('/mnt/h/3Tpioneer_bids'), _root=PosixPath('/mnt/h/3Tpioneer_bids/sub-ms1196/ses-20161004'), image=None, label=None, cond=None, id=24112560784)>
#  30%|███       | 174/575 [00:29<09:26,  1.41s/it]
# /usr/local/fsl/share/fsl/bin/fslmerge: line 2: 221615 Aborted                 (core dumped) /usr/local/fsl/bin/fslmerge "$@"
#  34%|███▎      | 194/575 [00:30<01:37,  3.91it/s]2024-11-10 17:09:06.813 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=1364, sesid=20170705)
#  48%|████▊     | 274/575 [00:32<00:08, 36.06it/s]2024-11-10 17:09:09.010 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=2085, sesid=20170130)
#  59%|█████▉    | 338/575 [00:34<00:03, 59.56it/s]2024-11-10 17:09:10.367 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=2001, sesid=20161222)
#  61%|██████    | 351/575 [00:34<00:04, 48.17it/s]2024-11-10 17:09:10.654 | INFO     | mri_data.utils:merge_images:29 - fslmerge -a /mnt/h/3Tpioneer_bids/sub-ms2120/ses-20170920/flair.t1.nii.gz /mnt/h/3Tpioneer_bids/sub-ms2120/ses-20170920/flair.nii.gz /mnt/h/3Tpioneer_bids/sub-ms2120/ses-20170920/t1.nii.gz
# Image Exception : #22 :: Failed to read volume /mnt/h/3Tpioneer_bids/sub-ms2120/ses-20170920/flair.nii.gz
# Error : Error: short read, file may be truncated
# terminate called after throwing an instance of 'std::runtime_error'
#   what():  Failed to read volume /mnt/h/3Tpioneer_bids/sub-ms2120/ses-20170920/flair.nii.gz
# Error : Error: short read, file may be truncated
#  61%|██████    | 351/575 [00:50<00:04, 48.17it/s]2024-11-10 17:09:33.952 | ERROR    | monai_training.preprocess:prepare_images:147 - Something went wrong merging images for <bound method Scan.info of Scan(subid='2120', sesid='20170920', _dataroot=PosixPath('/mnt/h/3Tpioneer_bids'), _root=PosixPath('/mnt/h/3Tpioneer_bids/sub-ms2120/ses-20170920'), image=None, label=None, cond=None, id=42762350400)>
#  61%|██████    | 352/575 [00:57<05:24,  1.46s/it]
# /usr/local/fsl/share/fsl/bin/fslmerge: line 2: 221757 Aborted                 (core dumped) /usr/local/fsl/bin/fslmerge "$@"
#  71%|███████   | 406/575 [01:00<00:08, 19.25it/s]2024-11-10 17:09:36.219 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=1245, sesid=20220219)
#  73%|███████▎  | 417/575 [01:00<00:05, 29.30it/s]2024-11-10 17:09:36.452 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=1394, sesid=20191012)
#  81%|████████  | 465/575 [01:01<00:02, 43.77it/s]2024-11-10 17:09:37.665 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=1379, sesid=20161022)
#  94%|█████████▍| 541/575 [01:02<00:00, 49.78it/s]2024-11-10 17:09:39.133 | WARNING  | monai_training.preprocess:prepare_images:138 - Couldn't prepare image for Scan(subid=2106, sesid=20170205)
# 100%|██████████| 575/575 [01:03<00:00,  9.02it/s]
# 2024-11-10 17:09:39.859 | INFO     | monai_training.preprocess:prepare_labels:167 - Prepare Labels
# 2024-11-10 17:09:39.859 | DEBUG    | monai_training.preprocess:prepare_labels:178 - choroid_t1_flair.pineal.pituitary.nii.gz
#   0%|          | 0/565 [00:00<?, ?it/s]2024-11-10 17:09:39.864 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.865 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2082, sesid=20170506)
# 2024-11-10 17:09:39.870 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.871 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.871 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.872 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.873 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.874 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2082, sesid=20170506)
# 2024-11-10 17:09:39.876 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.877 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1198, sesid=20170612)
# 2024-11-10 17:09:39.882 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.883 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.884 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.884 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.885 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.886 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1198, sesid=20170612)
# 2024-11-10 17:09:39.888 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.889 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1054, sesid=20161006)
# 2024-11-10 17:09:39.894 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.894 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.895 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.896 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.896 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.897 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1054, sesid=20161006)
# 2024-11-10 17:09:39.900 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.902 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2070, sesid=20160921)
# 2024-11-10 17:09:39.907 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.908 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.909 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.910 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.910 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.911 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2070, sesid=20160921)
# 2024-11-10 17:09:39.914 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.914 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1356, sesid=20180714)
# 2024-11-10 17:09:39.920 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.921 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.921 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.922 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.923 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.924 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1356, sesid=20180714)
# 2024-11-10 17:09:39.926 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.927 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1156, sesid=20170404)
# 2024-11-10 17:09:39.932 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.933 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.934 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.935 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.935 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.936 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1156, sesid=20170404)
# 2024-11-10 17:09:39.938 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.938 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2090, sesid=20170905)
# 2024-11-10 17:09:39.942 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.943 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.944 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.944 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.945 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.946 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2090, sesid=20170905)
# 2024-11-10 17:09:39.949 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.950 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1069, sesid=20220313)
# 2024-11-10 17:09:39.955 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.956 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.956 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.957 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.957 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.958 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1069, sesid=20220313)
# 2024-11-10 17:09:39.960 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.961 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2131, sesid=20190117)
# 2024-11-10 17:09:39.966 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.967 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.968 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.969 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.969 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.970 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2131, sesid=20190117)
#   2%|▏         | 9/565 [00:00<00:06, 82.79it/s]2024-11-10 17:09:39.972 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.973 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1415, sesid=20200323)
# 2024-11-10 17:09:39.978 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.979 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.980 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.980 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.981 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.982 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1415, sesid=20200323)
# 2024-11-10 17:09:39.985 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:39.986 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2098, sesid=20180515)
# 2024-11-10 17:09:39.993 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:39.994 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:39.994 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:39.996 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:39.996 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:39.997 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2098, sesid=20180515)
# 2024-11-10 17:09:39.999 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.000 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1529, sesid=20170119)
# 2024-11-10 17:09:40.004 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.005 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.006 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.007 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.007 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.008 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1529, sesid=20170119)
# 2024-11-10 17:09:40.010 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.011 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1169, sesid=20170607)
# 2024-11-10 17:09:40.015 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.016 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.017 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.018 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.018 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.019 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1169, sesid=20170607)
# 2024-11-10 17:09:40.021 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.022 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1047, sesid=20190506)
# 2024-11-10 17:09:40.026 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.027 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.027 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.028 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.028 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.029 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1047, sesid=20190506)
# 2024-11-10 17:09:40.031 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.032 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1489, sesid=20211109)
# 2024-11-10 17:09:40.037 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.038 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.038 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.039 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.039 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.040 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1489, sesid=20211109)
# 2024-11-10 17:09:40.042 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.043 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1324, sesid=20210123)
# 2024-11-10 17:09:40.047 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.047 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.048 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.049 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.049 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.050 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1324, sesid=20210123)
# 2024-11-10 17:09:40.052 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.053 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2170, sesid=20200117)
# 2024-11-10 17:09:40.057 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.057 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.058 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.058 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.059 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.060 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2170, sesid=20200117)
# 2024-11-10 17:09:40.062 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.063 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1022, sesid=20190807)
# 2024-11-10 17:09:40.067 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.067 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.068 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.068 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.069 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.069 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1022, sesid=20190807)
# 2024-11-10 17:09:40.072 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.073 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2128, sesid=20201017)
# 2024-11-10 17:09:40.077 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.077 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.078 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.078 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.079 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.080 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2128, sesid=20201017)
#   3%|▎         | 19/565 [00:00<00:06, 87.66it/s]2024-11-10 17:09:40.082 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.083 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2204, sesid=20201009)
# 2024-11-10 17:09:40.094 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.095 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.095 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.096 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.097 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.097 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2204, sesid=20201009)
# 2024-11-10 17:09:40.100 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.100 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1417, sesid=20170701)
# 2024-11-10 17:09:40.110 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.111 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.111 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.111 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.112 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.113 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1417, sesid=20170701)
# 2024-11-10 17:09:40.115 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.117 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1484, sesid=20220212)
# 2024-11-10 17:09:40.124 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.125 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.126 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.126 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.127 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.127 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1484, sesid=20220212)
# 2024-11-10 17:09:40.130 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.131 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1162, sesid=20200726)
# 2024-11-10 17:09:40.136 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.137 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.137 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.138 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.139 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.140 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1162, sesid=20200726)
# 2024-11-10 17:09:40.143 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.143 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1076, sesid=20170912)
# 2024-11-10 17:09:40.149 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.149 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.150 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.151 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:40.152 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:40.153 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1076, sesid=20170912)
# 2024-11-10 17:09:40.155 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:40.155 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1272, sesid=20211105)
# 2024-11-10 17:09:40.160 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:40.160 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.161 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.pineal-srs.pituitary-ch.nii.gz
# 2024-11-10 17:09:40.161 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair.nii.gz
# 2024-11-10 17:09:40.162 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair_ed.nii.gz
# 2024-11-10 17:09:40.163 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:40.164 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.165 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.pineal-srs.pituitary-ch.nii.gz
# 2024-11-10 17:09:40.165 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair.nii.gz
# 2024-11-10 17:09:40.166 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair_ed.nii.gz
# 2024-11-10 17:09:40.166 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.168 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:40.168 | DEBUG    | mri_data.file_manager:find_label:405 - Found choroid_t1_flair-ED.nii.gz for Scan(subid=1272, sesid=20211105)
# 2024-11-10 17:09:40.173 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pineal-ch.nii.gz
# 2024-11-10 17:09:40.173 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pineal-srs.nii.gz
# 2024-11-10 17:09:40.174 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pineal_srs.nii.gz
# 2024-11-10 17:09:40.174 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pineal-srs.nii.gz
# 2024-11-10 17:09:40.175 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pineal-srs.nii.gz
# 2024-11-10 17:09:40.175 | DEBUG    | mri_data.file_manager:find_label:405 - Found pineal-SRS.nii.gz for Scan(subid=1272, sesid=20211105)
# 2024-11-10 17:09:40.180 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pituitary-ch.nii.gz
# 2024-11-10 17:09:40.181 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pituitary-ch.nii.gz
# 2024-11-10 17:09:40.182 | DEBUG    | mri_data.file_manager:find_label:405 - Found pituitary-CH.nii.gz for Scan(subid=1272, sesid=20211105)
# 2024-11-10 17:09:40.199 | DEBUG    | mri_data.utils:combine_labels:109 - Setting choroid_t1_flair with id 1
# 2024-11-10 17:09:40.200 | DEBUG    | mri_data.utils:set_label_value:51 - thoo0
# 2024-11-10 17:09:40.215 | DEBUG    | mri_data.utils:set_label_value:57 - thoo1
# 2024-11-10 17:09:40.216 | DEBUG    | mri_data.utils:set_label_value:66 - fslmaths /mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/choroid_t1_flair-ED.nii.gz -bin -mul 1 /mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/tmp_choroid_t1_flair_1731276580.nii.gz
# 2024-11-10 17:09:40.927 | DEBUG    | mri_data.utils:set_label_value:68 - thoo4
# 2024-11-10 17:09:40.928 | DEBUG    | mri_data.utils:combine_labels:111 - thoo
# 2024-11-10 17:09:40.929 | DEBUG    | mri_data.utils:combine_labels:109 - Setting pineal with id 2
# 2024-11-10 17:09:40.929 | DEBUG    | mri_data.utils:set_label_value:51 - thoo0
# 2024-11-10 17:09:40.934 | DEBUG    | mri_data.utils:set_label_value:57 - thoo1
# 2024-11-10 17:09:40.935 | DEBUG    | mri_data.utils:set_label_value:66 - fslmaths /mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/pineal-SRS.nii.gz -bin -mul 2 /mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/tmp_pineal_1731276580.nii.gz
# 2024-11-10 17:09:41.754 | DEBUG    | mri_data.utils:set_label_value:68 - thoo4
# 2024-11-10 17:09:41.754 | DEBUG    | mri_data.utils:combine_labels:111 - thoo
# 2024-11-10 17:09:41.755 | DEBUG    | mri_data.utils:combine_labels:109 - Setting pituitary with id 3
# 2024-11-10 17:09:41.756 | DEBUG    | mri_data.utils:set_label_value:51 - thoo0
# 2024-11-10 17:09:41.829 | DEBUG    | mri_data.utils:set_label_value:57 - thoo1
# 2024-11-10 17:09:41.829 | DEBUG    | mri_data.utils:set_label_value:66 - fslmaths /mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/pituitary-CH.nii.gz -bin -mul 3 /mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/tmp_pituitary_1731276581.nii.gz
# 2024-11-10 17:09:42.509 | DEBUG    | mri_data.utils:set_label_value:68 - thoo4
# 2024-11-10 17:09:42.510 | DEBUG    | mri_data.utils:combine_labels:111 - thoo
# 2024-11-10 17:09:42.517 | DEBUG    | mri_data.utils:merge_labels:40 - Merging labels: ['/mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/tmp_choroid_t1_flair_1731276580.nii.gz', '/mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/tmp_pineal_1731276580.nii.gz', '/mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/tmp_pituitary_1731276581.nii.gz']
# 2024-11-10 17:09:43.600 | DEBUG    | mri_data.utils:merge_labels:46 - Merged label is: /mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz
# 2024-11-10 17:09:43.600 | SUCCESS  | mri_data.utils:combine_labels:123 - Saved combined label to /mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz
# 2024-11-10 17:09:43.603 | DEBUG    | mri_data.utils:combine_labels:127 - Removed temporary file tmp_choroid_t1_flair_1731276580.nii.gz
# 2024-11-10 17:09:43.605 | DEBUG    | mri_data.utils:combine_labels:127 - Removed temporary file tmp_pineal_1731276580.nii.gz
# 2024-11-10 17:09:43.608 | DEBUG    | mri_data.utils:combine_labels:127 - Removed temporary file tmp_pituitary_1731276581.nii.gz
# 2024-11-10 17:09:43.609 | SUCCESS  | monai_training.preprocess:log:22 - Saved /mnt/h/3Tpioneer_bids/sub-ms1272/ses-20211105/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz
# 2024-11-10 17:09:43.611 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.611 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1062, sesid=20180522)
# 2024-11-10 17:09:43.616 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.617 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.617 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.618 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.619 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.619 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1062, sesid=20180522)
# 2024-11-10 17:09:43.620 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.621 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2203, sesid=20210930)
# 2024-11-10 17:09:43.633 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.634 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.635 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.635 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.636 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.636 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2203, sesid=20210930)
# 2024-11-10 17:09:43.639 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.639 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1005, sesid=20200708)
# 2024-11-10 17:09:43.648 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.648 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.649 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.650 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.650 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.650 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1005, sesid=20200708)
#   5%|▍         | 28/565 [00:03<01:37,  5.51it/s]2024-11-10 17:09:43.654 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.655 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1334, sesid=20171212)
# 2024-11-10 17:09:43.659 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.659 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.660 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.660 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.661 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.662 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1334, sesid=20171212)
# 2024-11-10 17:09:43.664 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.665 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1145, sesid=20191126)
# 2024-11-10 17:09:43.670 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.670 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.671 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.672 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.672 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.673 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1145, sesid=20191126)
# 2024-11-10 17:09:43.675 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.675 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1473, sesid=20170629)
# 2024-11-10 17:09:43.681 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.682 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.682 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.683 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.684 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.684 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1473, sesid=20170629)
# 2024-11-10 17:09:43.687 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.688 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1522, sesid=20181031)
# 2024-11-10 17:09:43.692 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.693 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.694 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.694 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.695 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.695 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1522, sesid=20181031)
# 2024-11-10 17:09:43.697 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.699 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1088, sesid=20161112)
# 2024-11-10 17:09:43.704 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.705 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.706 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.707 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.707 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.707 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1088, sesid=20161112)
# 2024-11-10 17:09:43.710 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.711 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2167, sesid=20180616)
# 2024-11-10 17:09:43.716 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.716 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.717 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.718 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.718 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.719 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2167, sesid=20180616)
# 2024-11-10 17:09:43.721 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.722 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1204, sesid=20181002)
# 2024-11-10 17:09:43.726 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.727 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.727 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.728 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.728 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.729 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1204, sesid=20181002)
# 2024-11-10 17:09:43.731 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.731 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2132, sesid=20190825)
# 2024-11-10 17:09:43.736 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.737 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.737 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair.nii.gz
# 2024-11-10 17:09:43.738 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair_ed.nii.gz
# 2024-11-10 17:09:43.738 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.739 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.739 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair.nii.gz
# 2024-11-10 17:09:43.740 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair_ed.nii.gz
# 2024-11-10 17:09:43.740 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.741 | DEBUG    | mri_data.file_manager:find_label:403 - Checking choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.742 | DEBUG    | mri_data.file_manager:find_label:405 - Found choroid_t1_flair-ED.nii.gz for Scan(subid=2132, sesid=20190825)
# 2024-11-10 17:09:43.750 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pineal-ch.nii.gz
# 2024-11-10 17:09:43.751 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pineal-srs.nii.gz
# 2024-11-10 17:09:43.752 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pineal_srs.nii.gz
# 2024-11-10 17:09:43.753 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pineal-srs.nii.gz
# 2024-11-10 17:09:43.753 | DEBUG    | mri_data.file_manager:find_label:403 - Checking pineal-srs.nii.gz
# 2024-11-10 17:09:43.754 | DEBUG    | mri_data.file_manager:find_label:405 - Found pineal-SRS.nii.gz for Scan(subid=2132, sesid=20190825)
# 2024-11-10 17:09:43.767 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pituitary-ch.nii.gz
# 2024-11-10 17:09:43.767 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pituitary-srs.nii.gz
# 2024-11-10 17:09:43.768 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pituitary-ed.nii.gz
# 2024-11-10 17:09:43.769 | DEBUG    | mri_data.file_manager:find_label:401 - Testing pituitary-dt.nii.gz
# 2024-11-10 17:09:43.770 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.771 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2132, sesid=20190825)
#   6%|▋         | 36/565 [00:03<01:04,  8.22it/s]2024-11-10 17:09:43.776 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.777 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1264, sesid=20170806)
# 2024-11-10 17:09:43.782 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.783 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.784 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.785 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.786 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:09:43.787 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1264, sesid=20170806)
# 2024-11-10 17:09:43.791 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:09:43.793 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1130, sesid=20180902)
# 2024-11-10 17:09:43.798 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:09:43.799 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:09:43.800 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:09:43.800 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:09:43.801 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# ...
# 2024-11-10 17:11:11.974 | DEBUG    | mri_data.utils:set_label_value:68 - thoo4
# 2024-11-10 17:11:11.976 | DEBUG    | mri_data.utils:combine_labels:111 - thoo
# 2024-11-10 17:11:11.976 | DEBUG    | mri_data.utils:combine_labels:109 - Setting pituitary with id 3
# 2024-11-10 17:11:11.977 | DEBUG    | mri_data.utils:set_label_value:51 - thoo0
# 2024-11-10 17:11:11.981 | DEBUG    | mri_data.utils:set_label_value:57 - thoo1
# 2024-11-10 17:11:11.982 | DEBUG    | mri_data.utils:set_label_value:66 - fslmaths /mnt/h/3Tpioneer_bids/sub-ms1033/ses-20171117/pituitary-CH.nii.gz -bin -mul 3 /mnt/h/3Tpioneer_bids/sub-ms1033/ses-20171117/tmp_pituitary_1731276671.nii.gz
# 2024-11-10 17:11:12.654 | DEBUG    | mri_data.utils:set_label_value:68 - thoo4
# 2024-11-10 17:11:12.654 | DEBUG    | mri_data.utils:combine_labels:111 - thoo
# 2024-11-10 17:11:12.658 | DEBUG    | mri_data.utils:merge_labels:40 - Merging labels: ['/mnt/h/3Tpioneer_bids/sub-ms1033/ses-20171117/tmp_choroid_t1_flair_1731276670.nii.gz', '/mnt/h/3Tpioneer_bids/sub-ms1033/ses-20171117/tmp_pineal_1731276671.nii.gz', '/mnt/h/3Tpioneer_bids/sub-ms1033/ses-20171117/tmp_pituitary_1731276671.nii.gz']
# 2024-11-10 17:11:13.703 | DEBUG    | mri_data.utils:merge_labels:46 - Merged label is: /mnt/h/3Tpioneer_bids/sub-ms1033/ses-20171117/choroid_t1_flair-CH.pineal-CH.pituitary-CH.nii.gz
# 2024-11-10 17:11:13.703 | SUCCESS  | mri_data.utils:combine_labels:123 - Saved combined label to /mnt/h/3Tpioneer_bids/sub-ms1033/ses-20171117/choroid_t1_flair-CH.pineal-CH.pituitary-CH.nii.gz
# 2024-11-10 17:11:13.734 | DEBUG    | mri_data.utils:combine_labels:127 - Removed temporary file tmp_choroid_t1_flair_1731276670.nii.gz
# 2024-11-10 17:11:13.747 | DEBUG    | mri_data.utils:combine_labels:127 - Removed temporary file tmp_pineal_1731276671.nii.gz
# 2024-11-10 17:11:13.750 | DEBUG    | mri_data.utils:combine_labels:127 - Removed temporary file tmp_pituitary_1731276671.nii.gz
# 2024-11-10 17:11:13.751 | SUCCESS  | monai_training.preprocess:log:22 - Saved /mnt/h/3Tpioneer_bids/sub-ms1033/ses-20171117/choroid_t1_flair-CH.pineal-CH.pituitary-CH.nii.gz
# 2024-11-10 17:11:13.758 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.759 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1348, sesid=20181009)
# 2024-11-10 17:11:13.776 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.777 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.778 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.779 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.780 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.781 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1348, sesid=20181009)
#  98%|█████████▊| 552/565 [01:33<00:04,  2.86it/s]2024-11-10 17:11:13.787 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.788 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1532, sesid=20220217)
# 2024-11-10 17:11:13.797 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.798 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.798 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.799 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.800 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.801 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1532, sesid=20220217)
# 2024-11-10 17:11:13.805 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.805 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2043, sesid=20170707)
# 2024-11-10 17:11:13.810 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.812 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.813 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.814 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.815 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.815 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2043, sesid=20170707)
# 2024-11-10 17:11:13.818 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.819 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2168, sesid=20180530)
# 2024-11-10 17:11:13.824 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.825 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.826 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.826 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.827 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.828 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2168, sesid=20180530)
# 2024-11-10 17:11:13.830 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.832 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1027, sesid=20170127)
# 2024-11-10 17:11:13.838 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.839 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.840 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.841 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.842 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.842 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1027, sesid=20170127)
# 2024-11-10 17:11:13.846 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.847 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1300, sesid=20190115)
# 2024-11-10 17:11:13.855 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.856 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.857 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.858 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.858 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.859 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1300, sesid=20190115)
# 2024-11-10 17:11:13.861 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.862 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1257, sesid=20161208)
# 2024-11-10 17:11:13.866 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.867 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.867 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.868 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.868 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.869 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1257, sesid=20161208)
# 2024-11-10 17:11:13.871 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.871 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1203, sesid=20190814)
# 2024-11-10 17:11:13.875 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.876 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.877 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.878 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.878 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.879 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1203, sesid=20190814)
# 2024-11-10 17:11:13.881 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.882 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1241, sesid=20161122)
# 2024-11-10 17:11:13.888 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.889 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.890 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.892 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.893 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.894 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1241, sesid=20161122)
#  99%|█████████▉| 560/565 [01:34<00:01,  4.13it/s]2024-11-10 17:11:13.899 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.900 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=1441, sesid=20170519)
# 2024-11-10 17:11:13.906 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.907 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.907 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.908 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.909 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.910 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=1441, sesid=20170519)
# 2024-11-10 17:11:13.912 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.913 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2158, sesid=20190525)
# 2024-11-10 17:11:13.919 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.920 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.920 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.921 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.921 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.921 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2158, sesid=20190525)
# 2024-11-10 17:11:13.925 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.926 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2186, sesid=20200422)
# 2024-11-10 17:11:13.930 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.931 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.931 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.932 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.932 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.933 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2186, sesid=20200422)
# 2024-11-10 17:11:13.935 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.936 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2269, sesid=20220207)
# 2024-11-10 17:11:13.941 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.941 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.942 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.943 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.943 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.944 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2269, sesid=20220207)
# 2024-11-10 17:11:13.946 | DEBUG    | monai_training.preprocess:prepare_labels:196 - Need to create choroid_t1_flair.pineal.pituitary.nii.gz
# 2024-11-10 17:11:13.947 | INFO     | mri_data.utils:combine_labels:84 - Combining labels for Scan(subid=2250, sesid=20220122)
# 2024-11-10 17:11:13.951 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ch.nii.gz
# 2024-11-10 17:11:13.951 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-srs.nii.gz
# 2024-11-10 17:11:13.952 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-ed.nii.gz
# 2024-11-10 17:11:13.952 | DEBUG    | mri_data.file_manager:find_label:401 - Testing choroid_t1_flair-dt.nii.gz
# 2024-11-10 17:11:13.952 | DEBUG    | mri_data.file_manager:find_label:408 - No label in [] matched search
# 2024-11-10 17:11:13.953 | WARNING  | monai_training.preprocess:prepare_labels:206 - Couldn't prepare image for Scan(subid=2250, sesid=20220122)
# 100%|██████████| 565/565 [01:34<00:00,  6.00it/s]
# 2024-11-10 17:11:13.955 | INFO     | monai_training.preprocess:prepare_labels:229 - Dataset size: 28

# %%
if not load_data:
    dataset = training.assign_conditions(dataset, 0.2)
    dataset[0]

# %%
if not load_data:
    training_data = []
    test_data = []

    for scan in dataset:
        if scan.cond == 'tr':
            training_data.append({"image": scan.image, "label": scan.label})
        elif scan.cond == 'ts':
            test_data.append(scan.image)

# %% [markdown]
# ## Review

# %%
def display_slices(scan):
    img1 = nib.load(scan.image_path)
    img2 = nib.load(scan.label_path)

    data1 = img1.get_fdata()[:,:,:]
    data2 = img2.get_fdata()

    slice_sums = np.sum(data2, axis=(0, 1))
    
    print(slice_sums)

    max_slice_index = np.argmax(slice_sums)
    print(f"Max slice: {max_slice_index}")

    slice1 = data1[:, :, max_slice_index]
    slice2 = data2[:, :, max_slice_index]    

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(slice1, cmap='gray')
    plt.title(f"Image 1 - Slice {max_slice_index}")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(slice2, cmap='gray')
    plt.title(f"Image 2 - Slice {max_slice_index}")
    plt.axis('off')
    plt.show()

# %%
# display_slices(dataset[20])

# %% [markdown]
# In the original code, they include labels in the test data as well. Also they have a function that checks that there is nonzero number of voxels in the label

# %%
#? I don't know why they put labels for the test data. the brats segmentation code didn't.
# train_data = [{'image': path + '/flair.nii.gz', 'label': path + '/flair_chp_mask_qced.nii.gz'} for path in train_exams]
# test_data = [{'image': path + '/flair.nii.gz', 'label': path + '/flair_chp_mask_qced.nii.gz'} for path in test_exams]
if not load_data:
    train_data = []
    test_data = []
    for scan in dataset:
        if scan.cond == 'tr' and scan.has_label:
            train_data.append({"image": str(scan.image_path), "label": str(scan.label_path)})
        elif scan.cond == 'ts' and scan.has_label():
            test_data.append({"image": str(scan.image_path), "label": str(scan.label_path)})


    print(f"Train num total: {len(train_data)}")
    print(f"Test num: {len(test_data)}")

# %% [markdown]
# Create and save datalist

# %%
if not load_data:
    n_folds = 5
    datalist = {
        "testing": test_data,
        "training": [{"fold": i % n_folds, "image": c["image"], "label": c["label"]} for i,c in enumerate(train_data)]
    }

    if not os.path.isdir(work_dir):
        os.makedirs(work_dir)

    # dataroot_dir = "/mnt/h"
    # if not os.path.isdir(dataroot_dir):
    #     os.makedirs(dataroot_dir)

    datalist_file = os.path.join(work_dir, "datalist.json")
    with open(datalist_file, "w") as f:
        json.dump(datalist, f)

# %% [markdown]
# Load datalist

# %%
datalist['testing']
# Out:
# [{'image': '/media/smbshare/3Tpioneer_bids/sub-ms1109/ses-20180303/flair.t1.nii.gz',
#   'label': '/media/smbshare/3Tpioneer_bids/sub-ms1109/ses-20180303/choroid_t1_flair-ED.pineal-CH.pituitary-CH.nii.gz'},
#  {'image': '/media/smbshare/3Tpioneer_bids/sub-ms1188/ses-20200720/flair.t1.nii.gz',
#   'label': '/media/smbshare/3Tpioneer_bids/sub-ms1188/ses-20200720/choroid_t1_flair-ED.pineal-CH.pituitary-CH.nii.gz'},
#  {'image': '/media/smbshare/3Tpioneer_bids/sub-ms1259/ses-20200803/flair.t1.nii.gz',
#   'label': '/media/smbshare/3Tpioneer_bids/sub-ms1259/ses-20200803/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz'},
#  {'image': '/media/smbshare/3Tpioneer_bids/sub-ms1547/ses-20220321/flair.t1.nii.gz',
#   'label': '/media/smbshare/3Tpioneer_bids/sub-ms1547/ses-20220321/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz'},
#  {'image': '/media/smbshare/3Tpioneer_bids/sub-ms2081/ses-20170204/flair.t1.nii.gz',
#   'label': '/media/smbshare/3Tpioneer_bids/sub-ms2081/ses-20170204/choroid_t1_flair-ED.pineal-SRS.pituitary-CH.nii.gz'}]

# %%
missing_images = []
missing_labels = []
for scan in dataset:
    if not scan.image_path.is_file():
        missing_images.append(scan.image_path)
    if not scan.label_path.is_file():
        missing_images.append(scan.label_path)
print(missing_images)
print(missing_labels)
# Out:
# []
# []

# %%
runner = AutoRunner(
    work_dir=work_dir,
    algos=["swinunetr"],
    input={
        "modality": "MRI",
        "datalist": str(datalist_file),
        "dataroot": str(dataroot),
    },
)
# Out:
# 2024-11-08 17:07:52,570 - INFO - AutoRunner using work directory /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2
# 2024-11-08 17:07:52,571 - INFO - Found num_fold 5 based on the input datalist /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/datalist.json.
# 2024-11-08 17:07:52,572 - INFO - Setting num_fold 5 based on the input datalist /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/datalist.json.
# 2024-11-08 17:07:52,583 - INFO - Using user defined command running prefix , will override other settings

# %%
max_epochs = 100

train_param = {
    "num_epochs_per_validation": 1,
    #"num_images_per_batch": 2,
    "num_epochs": max_epochs,
    "num_warmup_epochs": 1,
}
runner.set_training_params(train_param)

# %%
runner.run()
# Out:
# 2024-11-08 17:07:58,820 - INFO - Running data analysis...
# 2024-11-08 17:07:58,821 - INFO - Found 1 GPUs for data analyzing!
# 100%|██████████| 24/24 [02:31<00:00,  6.31s/it]
# 2024-11-08 17:10:30,301 - INFO - Data spacing is not completely uniform. MONAI transforms may provide unexpected result
# 2024-11-08 17:10:30,301 - INFO - Writing data stats to /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/datastats.yaml.
# 2024-11-08 17:10:30,307 - INFO - Writing by-case data stats to /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/datastats_by_case.yaml, this may take a while.
# 2024-11-08 17:10:30,604 - INFO - BundleGen from https://github.com/Project-MONAI/research-contributions/releases/download/algo_templates/e4cf5a1.tar.gz
# algo_templates.tar.gz: 104kB [00:00, 432kB/s]
# 2024-11-08 17:10:30,852 - INFO - Downloaded: /tmp/tmpeehlz596/algo_templates.tar.gz
# 2024-11-08 17:10:30,852 - INFO - Expected md5 is None, skip md5 check for file /tmp/tmpeehlz596/algo_templates.tar.gz.
# 2024-11-08 17:10:30,852 - INFO - Writing into directory: /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2.
# 2024-11-08 17:10:30,896 - INFO - Generated:/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_0
# 2024-11-08 17:10:30,921 - INFO - Generated:/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_1
# 2024-11-08 17:10:30,946 - INFO - Generated:/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_2
# 2024-11-08 17:10:30,971 - INFO - Generated:/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_3
# 2024-11-08 17:10:30,996 - INFO - Generated:/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_4
# 2024-11-08 17:10:31,016 - INFO - ['python', '/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_0/scripts/train.py', 'run', "--config_file='/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_0/configs/hyper_parameters.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_0/configs/network.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_0/configs/transforms_infer.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_0/configs/transforms_train.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_0/configs/transforms_validate.yaml'", '--num_epochs_per_validation=1', '--num_epochs=100', '--num_warmup_epochs=1']
# monai.networks.nets.swin_unetr SwinUNETR.__init__:img_size: Argument `img_size` has been deprecated since version 1.3. It will be removed in version 1.5. The img_size argument is not required anymore and checks on the input size are run during forward().
# 2024-11-08 17:10:59,821 - INFO - Downloaded: /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_0/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt
# 2024-11-08 17:10:59,821 - INFO - Expected md5 is None, skip md5 check for file /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_0/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# 2024/11/08 17:10:59 INFO mlflow.tracking.fluent: Experiment with name 'Auto3DSeg' does not exist. Creating a new experiment.
# swinunetr_0 - training ...:  81%|████████  | 81/100 [3:00:47<42:24, 133.92s/round]
# 2024-11-08 20:12:49,213 - WARNING - swinunetr_0 - training: finished with early stop
# 2024-11-08 20:12:50,580 - INFO - ['python', '/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_1/scripts/train.py', 'run', "--config_file='/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_1/configs/hyper_parameters.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_1/configs/network.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_1/configs/transforms_infer.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_1/configs/transforms_train.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_1/configs/transforms_validate.yaml'", '--num_epochs_per_validation=1', '--num_epochs=100', '--num_warmup_epochs=1']
# monai.networks.nets.swin_unetr SwinUNETR.__init__:img_size: Argument `img_size` has been deprecated since version 1.3. It will be removed in version 1.5. The img_size argument is not required anymore and checks on the input size are run during forward().
# 2024-11-08 20:13:12,234 - INFO - Downloaded: /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_1/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt
# 2024-11-08 20:13:12,235 - INFO - Expected md5 is None, skip md5 check for file /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_1/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# 2024/11/08 20:13:12 INFO mlflow.tracking.fluent: Experiment with name 'Auto3DSeg' does not exist. Creating a new experiment.
# swinunetr_1 - training ...:  76%|███████▌  | 76/100 [2:48:03<53:04, 132.68s/round]
# 2024-11-08 23:02:18,175 - WARNING - swinunetr_1 - training: finished with early stop
# 2024-11-08 23:02:19,532 - INFO - ['python', '/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_2/scripts/train.py', 'run', "--config_file='/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_2/configs/hyper_parameters.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_2/configs/network.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_2/configs/transforms_infer.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_2/configs/transforms_train.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_2/configs/transforms_validate.yaml'", '--num_epochs_per_validation=1', '--num_epochs=100', '--num_warmup_epochs=1']
# monai.networks.nets.swin_unetr SwinUNETR.__init__:img_size: Argument `img_size` has been deprecated since version 1.3. It will be removed in version 1.5. The img_size argument is not required anymore and checks on the input size are run during forward().
# 2024-11-08 23:02:40,439 - INFO - Downloaded: /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_2/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt
# 2024-11-08 23:02:40,439 - INFO - Expected md5 is None, skip md5 check for file /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_2/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# 2024/11/08 23:02:40 INFO mlflow.tracking.fluent: Experiment with name 'Auto3DSeg' does not exist. Creating a new experiment.
# swinunetr_2 - training ...:  78%|███████▊  | 78/100 [2:51:30<48:22, 131.93s/round]
# 2024-11-09 01:55:12,324 - WARNING - swinunetr_2 - training: finished with early stop
# 2024-11-09 01:55:13,697 - INFO - ['python', '/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_3/scripts/train.py', 'run', "--config_file='/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_3/configs/hyper_parameters.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_3/configs/network.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_3/configs/transforms_infer.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_3/configs/transforms_train.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_3/configs/transforms_validate.yaml'", '--num_epochs_per_validation=1', '--num_epochs=100', '--num_warmup_epochs=1']
# monai.networks.nets.swin_unetr SwinUNETR.__init__:img_size: Argument `img_size` has been deprecated since version 1.3. It will be removed in version 1.5. The img_size argument is not required anymore and checks on the input size are run during forward().
# 2024-11-09 01:55:34,380 - INFO - Downloaded: /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_3/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt
# 2024-11-09 01:55:34,380 - INFO - Expected md5 is None, skip md5 check for file /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_3/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# 2024/11/09 01:55:34 INFO mlflow.tracking.fluent: Experiment with name 'Auto3DSeg' does not exist. Creating a new experiment.
# swinunetr_3 - training ...:  72%|███████▏  | 72/100 [2:45:33<1:04:22, 137.96s/round]
# 2024-11-09 04:42:15,234 - WARNING - swinunetr_3 - training: finished with early stop
# 2024-11-09 04:42:16,595 - INFO - ['python', '/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_4/scripts/train.py', 'run', "--config_file='/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_4/configs/hyper_parameters.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_4/configs/network.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_4/configs/transforms_infer.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_4/configs/transforms_train.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_4/configs/transforms_validate.yaml'", '--num_epochs_per_validation=1', '--num_epochs=100', '--num_warmup_epochs=1']
# monai.networks.nets.swin_unetr SwinUNETR.__init__:img_size: Argument `img_size` has been deprecated since version 1.3. It will be removed in version 1.5. The img_size argument is not required anymore and checks on the input size are run during forward().
# 2024-11-09 04:42:41,974 - INFO - Downloaded: /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_4/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt
# 2024-11-09 04:42:41,974 - INFO - Expected md5 is None, skip md5 check for file /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/swinunetr_4/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# 2024/11/09 04:42:42 INFO mlflow.tracking.fluent: Experiment with name 'Auto3DSeg' does not exist. Creating a new experiment.
# swinunetr_4 - training ...:  59%|█████▉    | 59/100 [2:25:44<1:41:16, 148.21s/round]
# 2024-11-09 07:09:21,038 - WARNING - swinunetr_4 - training: finished with early stop
# 2024-11-09 07:09:22,438 - INFO - Ensembling using single GPU!
# 2024-11-09 07:09:22,439 - INFO - The output_dir is not specified. /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/ensemble_output will be used to save ensemble predictions.
# 2024-11-09 07:09:22,439 - INFO - Directory /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/ensemble_output is created to save ensemble predictions
# 2024-11-09 07:09:22,463 - INFO - Auto3Dseg picked the following networks to ensemble:
# 2024-11-09 07:09:22,464 - INFO - swinunetr_0
# 2024-11-09 07:09:22,464 - INFO - swinunetr_1
# 2024-11-09 07:09:22,464 - INFO - swinunetr_2
# 2024-11-09 07:09:22,464 - INFO - swinunetr_3
# 2024-11-09 07:09:22,465 - INFO - swinunetr_4
# 2024-11-09 07:09:22,465 - INFO - Auto3Dseg ensemble prediction outputs will be saved in /home/srs-9/Projects/ms_mri/training_work_dirs/choroid_pineal_pituitary2/ensemble_output.
# Ensembling (rank 0)...:   0%|          | 0/5 [00:00<?, ?it/s]monai.networks.nets.swin_unetr SwinUNETR.__init__:img_size: Argument `img_size` has been deprecated since version 1.3. It will be removed in version 1.5. The img_size argument is not required anymore and checks on the input size are run during forward().
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# Ensembling (rank 0)...:  20%|██        | 1/5 [01:23<05:35, 83.78s/it]You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# Ensembling (rank 0)...:  40%|████      | 2/5 [02:44<04:06, 82.18s/it]You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# Ensembling (rank 0)...:  60%|██████    | 3/5 [04:15<02:52, 86.01s/it]You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# Ensembling (rank 0)...:  80%|████████  | 4/5 [05:49<01:29, 89.05s/it]You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# Ensembling (rank 0)...: 100%|██████████| 5/5 [06:58<00:00, 83.74s/it]
# 2024-11-09 07:16:21,187 - INFO - Auto3Dseg pipeline is completed successfully.

# %%
scan_path = "/mnt/t/Data/3Tpioneer_bids/sub-ms1001/ses-20170215/proc/lesion_index.t3m20-mni_reg.nii.gz"
img = nib.load(scan_path)

# %%
dataroot
# Out:
# PosixPath('/mnt/h/3Tpioneer_bids')

# %%
import numpy as np
from monai.auto3dseg import FgImageStats

input = {}
input['image'] = nib.load(dataset[0].image).get_fdata()
input['image'] = np.moveaxis(input['image'], -1, 0)
input['label'] = nib.load(dataset[0].label).get_fdata()
analyzer = FgImageStats(image_key='image', label_key='label')
print(analyzer(input)["image_foreground_stats"])
# Out:
# {intensity: [{'max': 1.249400019645691, 'mean': 0.585796878314022, 'median': 0.5439000129699707, 'min': 0.08329999446868896, 'stdev': 0.18512559606395076, 'percentile': [0.2657249830663204, 0.38679999113082886, 0.8765999674797058, 1.1460999548435211], 'percentile_00_5': 0.2657249830663204, 'percentile_10_0': 0.38679999113082886, 'percentile_90_0': 0.8765999674797058, 'percentile_99_5': 1.1460999548435211}, {'max': 1760.9627685546875, 'mean': 697.8903051592728, 'median': 649.264404296875, 'min': 36.2552604675293, 'stdev': 298.28309908667416, 'percentile': [136.68988418579102, 327.8006134033203, 1130.0955810546875, 1399.7532043457031], 'percentile_00_5': 136.68988418579102, 'percentile_10_0': 327.8006134033203, 'percentile_90_0': 1130.0955810546875, 'percentile_99_5': 1399.7532043457031}]}

# %%
idx = [3,0,1,2]
np.moveaxis(input['image'], -1, 0).shape
# Out:
# (2, 240, 300, 300)

# %%
img = nib.load(dataset[0].image)

# %%
img.affine
# Out:
# array([[ 7.98769057e-01, -7.61604309e-03, -4.38079834e-02,
#         -8.25058212e+01],
#        [ 7.60465860e-03,  7.99963772e-01, -4.16040421e-04,
#         -1.20926155e+02],
#        [ 4.38102484e-02,  0.00000000e+00,  7.98799574e-01,
#         -1.15306671e+02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00]])

# %%
nib.save(input['image'], 'test.nii')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 nib.save(input['image'], 'test.nii')
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/nibabel/loadsave.py:163, in save(img, filename, **kwargs)
#     161 # Save the type as expected
#     162 try:
# --> 163     img.to_filename(filename, **kwargs)
#     164 except ImageFileError:
#     165     pass
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_filename'
