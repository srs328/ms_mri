# %% [markdown]
# # Choroid Plexus Segmentation Training via Auto3DSeg

# %%
import os
import json
import nibabel as nib
import nibabel as nibabel
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import glob
import random
from monai.apps.auto3dseg import AutoRunner
from monai.config import print_config
from mri_preproc.paths import hemond_data, init_paths
import importlib
from dataclasses import asdict

print_config()
# Out:
# MONAI version: 1.3.2
# Numpy version: 1.26.4
# Pytorch version: 2.3.1+cu121
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 59a7211070538586369afd4a01eca0a7fe2e742e
# MONAI __file__: /home/<username>/.virtualenvs/monai/lib/python3.12/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: 5.4.0
# Nibabel version: 5.2.1
# scikit-image version: 0.24.0
# scipy version: 1.14.0
# Pillow version: 10.4.0
# Tensorboard version: 2.17.0
# gdown version: 5.2.0
# TorchVision version: 0.18.1+cu121
# tqdm version: 4.66.4
# lmdb version: 1.5.1
# psutil version: 6.0.0
# pandas version: 2.2.2
# einops version: 0.8.0
# transformers version: 4.42.4
# mlflow version: 2.14.3
# pynrrd version: 1.0.0
# clearml version: 1.16.2
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
init_paths.main()
from mri_preproc.paths.init_paths import DATA_HOME

importlib.reload(hemond_data)
# Out:
# <module 'mri_preproc.paths.hemond_data' from '/home/srs-9/Projects/ms_mri/mri_preproc/paths/hemond_data.py'>

# %% [markdown]
# ## Prep the database
#
# Get the data and labels organized

# %%
dataset0 = hemond_data.collect_proc_dataset("/mnt/t/Data/3Tpioneer_bids")
dataset_ref = hemond_data.scan_data_dir("/mnt/t/Data/MONAI/flair")

dataset = hemond_data.DataSet("DataSet", hemond_data.Scan)
for ref_data in dataset_ref:
    scan = dataset0.find_scan(ref_data.subid, ref_data.date)
    if scan:
        dataset.append(asdict(scan))
# Out:
# No scan exists for subject: ms1492 and session: 20190620

# %%
dataset = hemond_data.assign_conditions(dataset)
dataset[0]
# Out:
# Scan(subid='ms1001', date='20170215', root=PosixPath('/mnt/t/Data/3Tpioneer_bids/sub-ms1001/ses-20170215'), image=PosixPath('/mnt/t/Data/3Tpioneer_bids/sub-ms1001/ses-20170215/proc/flair-brain-mni_reg.nii.gz'), label=PosixPath('/mnt/t/Data/3Tpioneer_bids/sub-ms1001/ses-20170215/proc/lesion_index.t3m20-mni_reg.nii.gz'), cond='tr')

# %%
training_data = []
test_data = []

for scan in dataset:
    if scan.cond == 'tr':
        training_data.append({"image": scan.image, "label": scan.label})
    elif scan.cond == 'ts':
        test_data.append(scan.image)

# %% [markdown]
# ## Review

# %%
def display_slices(scan):
    img1 = nibabel.load(scan.image)
    img2 = nibabel.load(scan.label)

    data1 = img1.get_fdata()[:,:,:]
    data2 = img2.get_fdata()

    slice_sums = np.sum(data2, axis=(0, 1))
    
    print(slice_sums)

    max_slice_index = np.argmax(slice_sums)
    print(f"Max slice: {max_slice_index}")

    slice1 = data1[:, :, max_slice_index]
    slice2 = data2[:, :, max_slice_index]    

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(slice1, cmap='gray')
    plt.title(f"Image 1 - Slice {max_slice_index}")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(slice2, cmap='gray')
    plt.title(f"Image 2 - Slice {max_slice_index}")
    plt.axis('off')
    plt.show()

# %%
display_slices(dataset[20])
# Out:
# [0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 2.200e+01
#  7.400e+01 1.540e+02 1.460e+02 1.260e+02 2.150e+02 2.660e+02 2.480e+02
#  1.980e+02 1.320e+02 6.300e+01 5.800e+01 2.700e+01 1.700e+01 1.700e+02
#  4.450e+02 7.540e+02 1.071e+03 1.115e+03 1.387e+03 1.488e+03 1.235e+03
#  1.131e+03 1.461e+03 2.086e+03 2.422e+03 2.428e+03 2.287e+03 2.001e+03
#  1.725e+03 1.706e+03 1.528e+03 1.234e+03 1.066e+03 9.400e+02 7.000e+02
#  6.270e+02 7.910e+02 8.850e+02 8.100e+02 7.190e+02 5.950e+02 5.360e+02
#  5.590e+02 6.320e+02 7.770e+02 9.380e+02 1.141e+03 1.330e+03 1.093e+03
#  4.680e+02 9.500e+01 8.200e+01 1.080e+02 1.220e+02 1.330e+02 1.520e+02
#  1.030e+02 8.100e+01 9.400e+01 3.200e+01 0.000e+00 2.000e+00 0.000e+00
#  0.000e+00 1.000e+00 0.000e+00 0.000e+00 1.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00]
# Max slice: 74

# %% [markdown]
# In the original code, they include labels in the test data as well. Also they have a function that checks that there is nonzero number of voxels in the label

# %%
#? I don't know why they put labels for the test data. the brats segmentation code didn't.
# train_data = [{'image': path + '/flair.nii.gz', 'label': path + '/flair_chp_mask_qced.nii.gz'} for path in train_exams]
# test_data = [{'image': path + '/flair.nii.gz', 'label': path + '/flair_chp_mask_qced.nii.gz'} for path in test_exams]

train_data = []
test_data = []
for scan in dataset:
    if scan.cond == 'tr' and scan.has_label:
        train_data.append({"image": str(scan.image), "label": str(scan.label)})
    elif scan.cond == 'ts' and scan.has_label():
        test_data.append({"image": str(scan.image), "label": str(scan.label)})


print(f"Train num total: {len(train_data)}")
print(f"Test num: {len(test_data)}")
# Out:
# Train num total: 321
# Test num: 31

# %%
datalist = {
    "testing": test_data,
    "training": [{"fold": i % 4, "image": c["image"], "label": c["label"]} for i,c in enumerate(train_data)]
}

# %%
# sub_datalist = dict({'training':[], 'testing':[]})
# sub_datalist["training"] = datalist["training"][:200]
# sub_datalist["testing"] = datalist["testing"][:29]
# datalist = sub_datalist

# %%
datalist
# Out:
# {'testing': [{'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1024/ses-20170710/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1024/ses-20170710/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1026/ses-20181011/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1026/ses-20181011/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1044/ses-20170317/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1044/ses-20170317/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1062/ses-20180522/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1062/ses-20180522/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1064/ses-20170310/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1064/ses-20170310/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1069/ses-20220313/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1069/ses-20220313/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1074/ses-20190518/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1074/ses-20190518/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1115/ses-20170107/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1115/ses-20170107/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1138/ses-20170620/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1138/ses-20170620/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1157/ses-20170102/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1157/ses-20170102/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1158/ses-20170725/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1158/ses-20170725/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1183/ses-20170328/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1183/ses-20170328/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1189/ses-20200721/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1189/ses-20200721/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1202/ses-20180718/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1202/ses-20180718/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1209/ses-20170711/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1209/ses-20170711/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1232/ses-20170811/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1232/ses-20170811/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1270/ses-20200909/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1270/ses-20200909/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1282/ses-20161113/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1282/ses-20161113/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1296/ses-20180427/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1296/ses-20180427/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1311/ses-20161005/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1311/ses-20161005/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1322/ses-20180331/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1322/ses-20180331/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1327/ses-20170426/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1327/ses-20170426/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1332/ses-20200610/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1332/ses-20200610/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1351/ses-20210416/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1351/ses-20210416/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1376/ses-20161214/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1376/ses-20161214/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1392/ses-20201221/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1392/ses-20201221/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1398/ses-20210518/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1398/ses-20210518/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1400/ses-20171003/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1400/ses-20171003/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1414/ses-20200316/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1414/ses-20200316/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1436/ses-20180518/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1436/ses-20180518/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1462/ses-20191122/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1462/ses-20191122/proc/lesion_index.t3m20-mni_reg.nii.gz'}],
#  'training': [{'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1001/ses-20170215/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1001/ses-20170215/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1002/ses-20200521/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1002/ses-20200521/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1003/ses-20170329/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1003/ses-20170329/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1004/ses-20190906/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1004/ses-20190906/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1005/ses-20200708/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1005/ses-20200708/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1007/ses-20190907/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1007/ses-20190907/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1010/ses-20180208/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1010/ses-20180208/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1011/ses-20180911/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1011/ses-20180911/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1012/ses-20190903/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1012/ses-20190903/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1013/ses-20201109/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1013/ses-20201109/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1015/ses-20190326/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1015/ses-20190326/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1016/ses-20200421/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1016/ses-20200421/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1017/ses-20160921/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1017/ses-20160921/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1019/ses-20190608/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1019/ses-20190608/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1020/ses-20170927/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1020/ses-20170927/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1021/ses-20180928/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1021/ses-20180928/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1023/ses-20170813/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1023/ses-20170813/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1027/ses-20170127/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1027/ses-20170127/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1028/ses-20190608/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1028/ses-20190608/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1029/ses-20170816/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1029/ses-20170816/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1030/ses-20200304/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1030/ses-20200304/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1031/ses-20191116/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1031/ses-20191116/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1033/ses-20171117/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1033/ses-20171117/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1036/ses-20191027/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1036/ses-20191027/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1037/ses-20210508/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1037/ses-20210508/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1038/ses-20161031/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1038/ses-20161031/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1039/ses-20171206/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1039/ses-20171206/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1042/ses-20161013/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1042/ses-20161013/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1045/ses-20170418/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1045/ses-20170418/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1046/ses-20181109/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1046/ses-20181109/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1047/ses-20190506/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1047/ses-20190506/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1049/ses-20170815/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1049/ses-20170815/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1050/ses-20170624/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1050/ses-20170624/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1052/ses-20180803/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1052/ses-20180803/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1054/ses-20161006/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1054/ses-20161006/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1057/ses-20181212/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1057/ses-20181212/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1058/ses-20190102/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1058/ses-20190102/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1061/ses-20171230/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1061/ses-20171230/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1063/ses-20161017/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1063/ses-20161017/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1065/ses-20170127/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1065/ses-20170127/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1066/ses-20180828/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1066/ses-20180828/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1068/ses-20181220/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1068/ses-20181220/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1070/ses-20161025/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1070/ses-20161025/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1071/ses-20161201/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1071/ses-20161201/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1072/ses-20180615/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1072/ses-20180615/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1076/ses-20170912/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1076/ses-20170912/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1077/ses-20180522/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1077/ses-20180522/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1078/ses-20180412/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1078/ses-20180412/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1079/ses-20200927/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1079/ses-20200927/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1080/ses-20180416/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1080/ses-20180416/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1082/ses-20161218/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1082/ses-20161218/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1083/ses-20180227/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1083/ses-20180227/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1085/ses-20220228/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1085/ses-20220228/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1087/ses-20200717/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1087/ses-20200717/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1088/ses-20161112/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1088/ses-20161112/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1089/ses-20210612/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1089/ses-20210612/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1090/ses-20201206/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1090/ses-20201206/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1093/ses-20171106/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1093/ses-20171106/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1094/ses-20160902/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1094/ses-20160902/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1097/ses-20200522/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1097/ses-20200522/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1098/ses-20171105/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1098/ses-20171105/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1100/ses-20180703/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1100/ses-20180703/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1101/ses-20170827/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1101/ses-20170827/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1102/ses-20190503/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1102/ses-20190503/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1103/ses-20191214/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1103/ses-20191214/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1104/ses-20190418/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1104/ses-20190418/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1105/ses-20171208/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1105/ses-20171208/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1106/ses-20190420/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1106/ses-20190420/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1107/ses-20170502/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1107/ses-20170502/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1108/ses-20180110/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1108/ses-20180110/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1109/ses-20180303/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1109/ses-20180303/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1111/ses-20161211/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1111/ses-20161211/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1112/ses-20190514/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1112/ses-20190514/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1113/ses-20170526/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1113/ses-20170526/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1116/ses-20200828/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1116/ses-20200828/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1117/ses-20180924/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1117/ses-20180924/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1118/ses-20181217/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1118/ses-20181217/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1119/ses-20161010/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1119/ses-20161010/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1121/ses-20170530/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1121/ses-20170530/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1122/ses-20170427/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1122/ses-20170427/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1124/ses-20160929/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1124/ses-20160929/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1125/ses-20160919/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1125/ses-20160919/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1126/ses-20170609/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1126/ses-20170609/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1129/ses-20200120/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1129/ses-20200120/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1130/ses-20180902/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1130/ses-20180902/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1131/ses-20161209/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1131/ses-20161209/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1132/ses-20181117/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1132/ses-20181117/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1133/ses-20170308/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1133/ses-20170308/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1134/ses-20180103/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1134/ses-20180103/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1135/ses-20170721/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1135/ses-20170721/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1136/ses-20171109/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1136/ses-20171109/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1140/ses-20201020/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1140/ses-20201020/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1141/ses-20200819/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1141/ses-20200819/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1142/ses-20170715/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1142/ses-20170715/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1143/ses-20190126/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1143/ses-20190126/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1144/ses-20201002/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1144/ses-20201002/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1145/ses-20191126/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1145/ses-20191126/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1146/ses-20190821/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1146/ses-20190821/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1148/ses-20170618/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1148/ses-20170618/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1150/ses-20170724/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1150/ses-20170724/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1152/ses-20170529/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1152/ses-20170529/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1153/ses-20181010/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1153/ses-20181010/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1154/ses-20170412/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1154/ses-20170412/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1155/ses-20180708/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1155/ses-20180708/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1156/ses-20170404/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1156/ses-20170404/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1161/ses-20191028/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1161/ses-20191028/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1162/ses-20200726/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1162/ses-20200726/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1163/ses-20180907/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1163/ses-20180907/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1164/ses-20190709/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1164/ses-20190709/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1165/ses-20160910/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1165/ses-20160910/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1167/ses-20170503/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1167/ses-20170503/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1169/ses-20170607/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1169/ses-20170607/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1170/ses-20190808/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1170/ses-20190808/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1171/ses-20161116/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1171/ses-20161116/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1172/ses-20190214/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1172/ses-20190214/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1174/ses-20171119/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1174/ses-20171119/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1175/ses-20201117/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1175/ses-20201117/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1176/ses-20180618/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1176/ses-20180618/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1177/ses-20180813/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1177/ses-20180813/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1178/ses-20191023/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1178/ses-20191023/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1179/ses-20190902/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1179/ses-20190902/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1182/ses-20170131/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1182/ses-20170131/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1186/ses-20170517/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1186/ses-20170517/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1188/ses-20200720/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1188/ses-20200720/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1191/ses-20190124/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1191/ses-20190124/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1192/ses-20190320/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1192/ses-20190320/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1196/ses-20161004/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1196/ses-20161004/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1198/ses-20170612/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1198/ses-20170612/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1199/ses-20190531/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1199/ses-20190531/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1200/ses-20170128/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1200/ses-20170128/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1201/ses-20161021/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1201/ses-20161021/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1203/ses-20190814/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1203/ses-20190814/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1204/ses-20181002/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1204/ses-20181002/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1207/ses-20180624/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1207/ses-20180624/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1208/ses-20171221/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1208/ses-20171221/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1210/ses-20161104/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1210/ses-20161104/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1211/ses-20170117/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1211/ses-20170117/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1214/ses-20180815/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1214/ses-20180815/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1215/ses-20180429/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1215/ses-20180429/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1216/ses-20170113/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1216/ses-20170113/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1217/ses-20170503/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1217/ses-20170503/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1218/ses-20170821/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1218/ses-20170821/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1219/ses-20170620/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1219/ses-20170620/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1220/ses-20170810/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1220/ses-20170810/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1223/ses-20180405/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1223/ses-20180405/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1224/ses-20181007/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1224/ses-20181007/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1225/ses-20161203/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1225/ses-20161203/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1226/ses-20170428/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1226/ses-20170428/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1228/ses-20170616/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1228/ses-20170616/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1231/ses-20181209/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1231/ses-20181209/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1234/ses-20180214/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1234/ses-20180214/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1235/ses-20161121/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1235/ses-20161121/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1237/ses-20190619/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1237/ses-20190619/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1238/ses-20190621/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1238/ses-20190621/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1239/ses-20170113/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1239/ses-20170113/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1240/ses-20170615/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1240/ses-20170615/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1241/ses-20161122/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1241/ses-20161122/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1242/ses-20170830/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1242/ses-20170830/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1246/ses-20160915/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1246/ses-20160915/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1247/ses-20190905/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1247/ses-20190905/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1248/ses-20160922/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1248/ses-20160922/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1250/ses-20170623/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1250/ses-20170623/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1251/ses-20200507/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1251/ses-20200507/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1252/ses-20180920/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1252/ses-20180920/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1254/ses-20171226/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1254/ses-20171226/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1256/ses-20170601/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1256/ses-20170601/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1257/ses-20161208/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1257/ses-20161208/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1258/ses-20180715/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1258/ses-20180715/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1259/ses-20200803/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1259/ses-20200803/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1260/ses-20210211/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1260/ses-20210211/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1261/ses-20180826/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1261/ses-20180826/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1262/ses-20170402/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1262/ses-20170402/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1263/ses-20200809/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1263/ses-20200809/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1264/ses-20170806/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1264/ses-20170806/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1265/ses-20180127/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1265/ses-20180127/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1267/ses-20210105/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1267/ses-20210105/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1268/ses-20210427/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1268/ses-20210427/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1271/ses-20200503/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1271/ses-20200503/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1272/ses-20211105/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1272/ses-20211105/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1273/ses-20201227/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1273/ses-20201227/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1274/ses-20180504/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1274/ses-20180504/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1276/ses-20190329/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1276/ses-20190329/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1278/ses-20180527/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1278/ses-20180527/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1279/ses-20201012/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1279/ses-20201012/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1280/ses-20220317/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1280/ses-20220317/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1281/ses-20180705/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1281/ses-20180705/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1283/ses-20200810/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1283/ses-20200810/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1285/ses-20161105/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1285/ses-20161105/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1287/ses-20200515/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1287/ses-20200515/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1289/ses-20200821/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1289/ses-20200821/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1290/ses-20170702/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1290/ses-20170702/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
# ...
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1366/ses-20170306/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1366/ses-20170306/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1367/ses-20171028/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1367/ses-20171028/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1369/ses-20190606/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1369/ses-20190606/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1370/ses-20210421/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1370/ses-20210421/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1371/ses-20170208/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1371/ses-20170208/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1373/ses-20180717/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1373/ses-20180717/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1374/ses-20170106/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1374/ses-20170106/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1375/ses-20181016/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1375/ses-20181016/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1377/ses-20160929/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1377/ses-20160929/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1381/ses-20181109/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1381/ses-20181109/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1382/ses-20170511/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1382/ses-20170511/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1383/ses-20181105/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1383/ses-20181105/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1384/ses-20170203/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1384/ses-20170203/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1385/ses-20210630/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1385/ses-20210630/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1388/ses-20170915/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1388/ses-20170915/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1391/ses-20201207/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1391/ses-20201207/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1395/ses-20180810/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1395/ses-20180810/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1396/ses-20170126/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1396/ses-20170126/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1401/ses-20170801/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1401/ses-20170801/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1402/ses-20191019/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1402/ses-20191019/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1404/ses-20180329/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1404/ses-20180329/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1405/ses-20190407/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1405/ses-20190407/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1406/ses-20200929/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1406/ses-20200929/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1415/ses-20200323/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1415/ses-20200323/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1416/ses-20211019/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1416/ses-20211019/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1417/ses-20170701/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1417/ses-20170701/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1419/ses-20200505/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1419/ses-20200505/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1421/ses-20210122/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1421/ses-20210122/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1422/ses-20200825/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1422/ses-20200825/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1423/ses-20170302/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1423/ses-20170302/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1425/ses-20210420/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1425/ses-20210420/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1426/ses-20170818/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1426/ses-20170818/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1427/ses-20190122/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1427/ses-20190122/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1428/ses-20210711/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1428/ses-20210711/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1429/ses-20180414/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1429/ses-20180414/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1431/ses-20210410/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1431/ses-20210410/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1432/ses-20170622/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1432/ses-20170622/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1433/ses-20201230/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1433/ses-20201230/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1435/ses-20200903/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1435/ses-20200903/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1437/ses-20210503/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1437/ses-20210503/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1441/ses-20170519/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1441/ses-20170519/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1442/ses-20170720/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1442/ses-20170720/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1443/ses-20200923/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1443/ses-20200923/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1444/ses-20211123/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1444/ses-20211123/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1446/ses-20181208/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1446/ses-20181208/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1451/ses-20220301/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1451/ses-20220301/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1452/ses-20220130/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1452/ses-20220130/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1453/ses-20160916/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1453/ses-20160916/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1455/ses-20171031/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1455/ses-20171031/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1457/ses-20210916/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1457/ses-20210916/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1460/ses-20211222/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1460/ses-20211222/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1461/ses-20210624/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1461/ses-20210624/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1463/ses-20180210/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1463/ses-20180210/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1464/ses-20191217/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1464/ses-20191217/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1465/ses-20160911/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1465/ses-20160911/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1467/ses-20220502/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1467/ses-20220502/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1468/ses-20210723/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1468/ses-20210723/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1469/ses-20210909/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1469/ses-20210909/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1470/ses-20200327/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1470/ses-20200327/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1471/ses-20200714/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1471/ses-20200714/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1472/ses-20200921/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1472/ses-20200921/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1473/ses-20170629/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1473/ses-20170629/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1475/ses-20210303/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1475/ses-20210303/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1476/ses-20180414/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1476/ses-20180414/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1477/ses-20220115/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1477/ses-20220115/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1479/ses-20161018/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1479/ses-20161018/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1481/ses-20170418/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1481/ses-20170418/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1482/ses-20170309/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1482/ses-20170309/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1484/ses-20220212/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1484/ses-20220212/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 1,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1486/ses-20210224/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1486/ses-20210224/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 2,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1487/ses-20210920/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1487/ses-20210920/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 3,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1488/ses-20210905/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1488/ses-20210905/proc/lesion_index.t3m20-mni_reg.nii.gz'},
#   {'fold': 0,
#    'image': '/mnt/t/Data/3Tpioneer_bids/sub-ms1489/ses-20211109/proc/flair-brain-mni_reg.nii.gz',
#    'label': '/mnt/t/Data/3Tpioneer_bids/sub-ms1489/ses-20211109/proc/lesion_index.t3m20-mni_reg.nii.gz'}]}

# %%
len(datalist['training'])
# Out:
# 321

# %%
work_dir = "/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16"
# work_dir = "/home/hemondlab/Dev/ms_mri/training_work_dirs/cp_work_dir6"
if not os.path.isdir(work_dir):
    os.makedirs(work_dir)

dataroot_dir = DATA_HOME
if not os.path.isdir(dataroot_dir):
    os.makedirs(dataroot_dir)

datalist_file = os.path.join(work_dir, "datalist.json")
with open(datalist_file, "w") as f:
    json.dump(datalist, f)

# %%
runner = AutoRunner(
    work_dir=work_dir,
    algos=["swinunetr"],
    input={
        "modality": "MRI",
        "datalist": datalist_file,
        "dataroot": dataroot_dir,
    },
)
# Out:
# 2024-07-22 00:44:29,513 - INFO - AutoRunner using work directory /home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16
# 2024-07-22 00:44:29,519 - INFO - Found num_fold 4 based on the input datalist /home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/datalist.json.
# 2024-07-22 00:44:29,520 - INFO - Setting num_fold 4 based on the input datalist /home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/datalist.json.
# 2024-07-22 00:44:29,523 - INFO - Using user defined command running prefix , will override other settings

# %%
max_epochs = 50

train_param = {
    "num_epochs_per_validation": 1,
    #"num_images_per_batch": 2,
    "num_epochs": max_epochs,
    "num_warmup_epochs": 1,
}
runner.set_training_params(train_param)

# %%
runner.run()
# Out:
# 2024-07-22 00:44:29,549 - INFO - Running data analysis...
# 2024-07-22 00:44:29,551 - INFO - Found 1 GPUs for data analyzing!
# 100%|██████████| 321/321 [01:06<00:00,  4.84it/s]
# 2024-07-22 00:45:44,997 - INFO - Writing data stats to /home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/datastats.yaml.
# 2024-07-22 00:45:45,223 - INFO - Writing by-case data stats to /home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/datastats_by_case.yaml, this may take a while.
# 2024-07-22 00:45:51,139 - INFO - BundleGen from https://github.com/Project-MONAI/research-contributions/releases/download/algo_templates/e4cf5a1.tar.gz
# algo_templates.tar.gz: 104kB [00:00, 235kB/s]
# 2024-07-22 00:45:51,632 - INFO - Downloaded: /tmp/tmpxsq_ya5u/algo_templates.tar.gz
# 2024-07-22 00:45:51,632 - INFO - Expected md5 is None, skip md5 check for file /tmp/tmpxsq_ya5u/algo_templates.tar.gz.
# 2024-07-22 00:45:51,633 - INFO - Writing into directory: /home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16.
# 2024-07-22 00:45:52,128 - INFO - Generated:/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0
# 2024-07-22 00:45:52,504 - INFO - Generated:/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_1
# 2024-07-22 00:45:53,024 - INFO - Generated:/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_2
# 2024-07-22 00:45:53,427 - INFO - Generated:/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_3
# 2024-07-22 00:45:53,449 - INFO - ['python', '/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/scripts/train.py', 'run', "--config_file='/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/configs/hyper_parameters.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/configs/network.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/configs/transforms_infer.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/configs/transforms_train.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/configs/transforms_validate.yaml'", '--num_epochs_per_validation=1', '--num_epochs=50', '--num_warmup_epochs=1']
# monai.networks.nets.swin_unetr SwinUNETR.__init__:img_size: Argument `img_size` has been deprecated since version 1.3. It will be removed in version 1.5. The img_size argument is not required anymore and checks on the input size are run during forward().
# 2024-07-22 00:46:22,197 - INFO - Downloaded: /home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt
# 2024-07-22 00:46:22,197 - INFO - Expected md5 is None, skip md5 check for file /home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/pretrained_model/swin_unetr.base_5000ep_f48_lr2e-4_pretrained.pt.
# 2024/07/22 00:46:22 INFO mlflow.tracking.fluent: Experiment with name 'Auto3DSeg' does not exist. Creating a new experiment.
# swinunetr_0 - training ...:  86%|████████▌ | 43/50 [17:41:41<2:52:49, 1481.42s/round]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 runner.run()
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/monai/apps/auto3dseg/auto_runner.py:878, in AutoRunner.run(self)
#     876 if len(history) > 0:
#     877     if not self.hpo:
# --> 878         self._train_algo_in_sequence(history)
#     879     else:
#     880         self._train_algo_in_nni(history)
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/monai/apps/auto3dseg/auto_runner.py:728, in AutoRunner._train_algo_in_sequence(self, history)
#     726 algo = algo_dict[AlgoKeys.ALGO]
#     727 if has_option(algo.train, "device_setting"):
# --> 728     algo.train(self.train_params, self.device_setting)
#     729 else:
#     730     algo.train(self.train_params)
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/monai/apps/auto3dseg/bundle_gen.py:300, in BundleAlgo.train(self, train_params, device_setting)
#     297     train_params.pop("CUDA_VISIBLE_DEVICES")
#     299 cmd, _unused_return = self._create_cmd(train_params)
# --> 300 return self._run_cmd(cmd)
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/monai/apps/auto3dseg/bundle_gen.py:277, in BundleAlgo._run_cmd(self, cmd, devices_info)
#     273     return _run_cmd_torchrun(
#     274         cmd, nnodes=1, nproc_per_node=self.device_setting["n_devices"], env=ps_environ, check=True
#     275     )
#     276 else:
# --> 277     return run_cmd(cmd.split(), run_cmd_verbose=True, env=ps_environ, check=True)
#
# File ~/.virtualenvs/monai/lib/python3.12/site-packages/monai/utils/misc.py:873, in run_cmd(cmd_list, **kwargs)
#     871     monai.apps.utils.get_logger("run_cmd").info(f"{cmd_list}")
#     872 try:
# --> 873     return subprocess.run(cmd_list, **kwargs)
#     874 except subprocess.CalledProcessError as e:
#     875     if not debug:
#
# File ~/.asdf/installs/python/3.12.4/lib/python3.12/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['python', '/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/scripts/train.py', 'run', "--config_file='/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/configs/hyper_parameters.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/configs/network.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/configs/transforms_infer.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/configs/transforms_train.yaml,/home/srs-9/Projects/ms_mri/training_work_dirs/cp_work_dir16/swinunetr_0/configs/transforms_validate.yaml'", '--num_epochs_per_validation=1', '--num_epochs=50', '--num_warmup_epochs=1']' died with <Signals.SIGKILL: 9>.
